# %% [markdown]
# 位移/路程 重构动量因子

# %%
import polars as pl
import numpy as np

# 读取数据
data = pl.read_parquet("hourly_data.pa")

df = data.sort('open_time').sort('symbol')

# 定义窗口大小
window_size = 15

# 计算每个symbol每时刻的价格差
df = df.with_columns([
    pl.col("close").diff().abs().over("symbol").alias("price_diff"),
    (pl.col('close') / (pl.col('close').shift(1).over('symbol')) - 1).alias('return')
])

# 计算价格变化
df = df.with_columns([
    (pl.col("close") - pl.col("close").shift(window_size)).over("symbol").alias("price_change")
])

# 计算绝对价格变化的总和
df = df.with_columns([
    pl.col("price_diff").rolling_sum(window_size, min_periods=window_size).over("symbol").alias("abs_price_change_sum")
])

# 计算价格位移与路程之比因子
df = df.with_columns([
    (pl.col("price_change") / pl.col("abs_price_change_sum")).alias("momentum_factor")
])

df
# Out:
# shape: (2_483_434, 17)
# ┌─────────────┬────────┬────────┬────────┬───┬───────────┬─────────────┬─────────────┬─────────────┐
# │ open_time   ┆ open   ┆ high   ┆ low    ┆ … ┆ return    ┆ price_chang ┆ abs_price_c ┆ momentum_fa │
# │ ---         ┆ ---    ┆ ---    ┆ ---    ┆   ┆ ---       ┆ e           ┆ hange_sum   ┆ ctor        │
# │ datetime[μs ┆ f64    ┆ f64    ┆ f64    ┆   ┆ f64       ┆ ---         ┆ ---         ┆ ---         │
# │ ]           ┆        ┆        ┆        ┆   ┆           ┆ f64         ┆ f64         ┆ f64         │
# ╞═════════════╪════════╪════════╪════════╪═══╪═══════════╪═════════════╪═════════════╪═════════════╡
# │ 2022-09-09  ┆ 0.4728 ┆ 0.4874 ┆ 0.3663 ┆ … ┆ null      ┆ null        ┆ null        ┆ null        │
# │ 13:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-09-09  ┆ 0.451  ┆ 0.4609 ┆ 0.4277 ┆ … ┆ 0.018182  ┆ null        ┆ null        ┆ null        │
# │ 14:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-09-09  ┆ 0.4594 ┆ 0.4734 ┆ 0.4416 ┆ … ┆ -0.008057 ┆ null        ┆ null        ┆ null        │
# │ 15:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-09-09  ┆ 0.4554 ┆ 0.458  ┆ 0.4175 ┆ … ┆ -0.056641 ┆ null        ┆ null        ┆ null        │
# │ 16:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-09-09  ┆ 0.4297 ┆ 0.4418 ┆ 0.4071 ┆ … ┆ -0.032814 ┆ null        ┆ null        ┆ null        │
# │ 17:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ …           ┆ …      ┆ …      ┆ …      ┆ … ┆ …         ┆ …           ┆ …           ┆ …           │
# │ 2022-12-31  ┆ 0.1494 ┆ 0.1498 ┆ 0.1494 ┆ … ┆ 0.001339  ┆ -0.0012     ┆ 0.0038      ┆ -0.315789   │
# │ 19:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-12-31  ┆ 0.1496 ┆ 0.1497 ┆ 0.1494 ┆ … ┆ 0.0       ┆ -0.0006     ┆ 0.0032      ┆ -0.1875     │
# │ 20:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-12-31  ┆ 0.1496 ┆ 0.1497 ┆ 0.149  ┆ … ┆ -0.004011 ┆ -0.0011     ┆ 0.0037      ┆ -0.297297   │
# │ 21:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-12-31  ┆ 0.149  ┆ 0.1491 ┆ 0.1478 ┆ … ┆ -0.004698 ┆ -0.0022     ┆ 0.004       ┆ -0.55       │
# │ 22:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# │ 2022-12-31  ┆ 0.1483 ┆ 0.1484 ┆ 0.1476 ┆ … ┆ -0.00472  ┆ -0.0028     ┆ 0.0046      ┆ -0.608696   │
# │ 23:00:00    ┆        ┆        ┆        ┆   ┆           ┆             ┆             ┆             │
# └─────────────┴────────┴────────┴────────┴───┴───────────┴─────────────┴─────────────┴─────────────┘

# %%
factors = df.select(['open_time', 'symbol', 'momentum_factor'])

from factor_analysis.factor_analysis import FactorAnalysis

# 使用示例
analysis = FactorAnalysis(factors, data)
analysis.run_full_analysis()
# Out:
# long:
# ann_return = 0.0918  sharpe = 0.0831  maxdd = 0.7872  calmar_ratio = 0.1166
#
# short:
# ann_return = 1.0275  sharpe = 0.9404  maxdd = 0.5947  calmar_ratio = 1.7278
#
# bench:
# ann_return = 0.5575  sharpe = 0.513  maxdd = 0.6895  calmar_ratio = 0.8085
#
# long_short:
# ann_return = -1.3737  sharpe = -4.3809  maxdd = 3.8706  calmar_ratio = -0.3549
#
# long_bench:
# ann_return = -0.9037  sharpe = -5.6832  maxdd = 2.6562  calmar_ratio = -0.3402
#
# bench_long:
# ann_return = 0.0277  sharpe = 0.1742  maxdd = 0.3284  calmar_ratio = 0.0844
#
# short_long:
# ann_return = 0.4977  sharpe = 1.5872  maxdd = 0.2849  calmar_ratio = 1.7467
#
# short_bench:
# ann_return = 0.032  sharpe = 0.2024  maxdd = 0.2897  calmar_ratio = 0.1103
#
# bench_short:
# ann_return = -0.908  sharpe = -5.7497  maxdd = 2.6403  calmar_ratio = -0.3439
# group_1:
# ann_return = 2.1705  sharpe = 1.8652  maxdd = 0.426  calmar_ratio = 5.095
#
# group_2:
# ann_return = 1.2298  sharpe = 1.0891  maxdd = 0.7505  calmar_ratio = 1.6386
#
# group_3:
# ann_return = 0.9415  sharpe = 0.8503  maxdd = 0.6189  calmar_ratio = 1.5213
#
# group_4:
# ann_return = 0.6604  sharpe = 0.5967  maxdd = 0.5901  calmar_ratio = 1.119
#
# group_5:
# ann_return = -0.1074  sharpe = -0.0959  maxdd = 0.8722  calmar_ratio = -0.1232
#
# group_6:
# ann_return = -0.2025  sharpe = -0.1806  maxdd = 1.0066  calmar_ratio = -0.2012
#
# group_7:
# ann_return = -0.8883  sharpe = -0.7915  maxdd = 2.1898  calmar_ratio = -0.4057
#
# group_8:
# ann_return = -0.2362  sharpe = -0.2049  maxdd = 0.8975  calmar_ratio = -0.2632
#
# group_9:
# ann_return = 0.3955  sharpe = 0.3371  maxdd = 0.9332  calmar_ratio = 0.4238
#
# group_10:
# ann_return = 1.0981  sharpe = 0.8827  maxdd = 0.7389  calmar_ratio = 1.4862
#
# -----------------------------------------
# group_difference_1:
# ann_return = 1.175  sharpe = 3.1132  maxdd = 0.1806  calmar_ratio = 6.5046
#
# group_difference_2:
# ann_return = 0.2342  sharpe = 0.7136  maxdd = 0.3812  calmar_ratio = 0.6145
#
# group_difference_3:
# ann_return = -0.054  sharpe = -0.1814  maxdd = 0.5916  calmar_ratio = -0.0913
#
# group_difference_4:
# ann_return = -0.3352  sharpe = -1.1005  maxdd = 1.2224  calmar_ratio = -0.2742
#
# group_difference_5:
# ann_return = -1.1029  sharpe = -3.6144  maxdd = 3.4108  calmar_ratio = -0.3234
#
# group_difference_6:
# ann_return = -1.198  sharpe = -3.9852  maxdd = 3.7005  calmar_ratio = -0.3237
#
# group_difference_7:
# ann_return = -1.8838  sharpe = -6.0134  maxdd = 5.5087  calmar_ratio = -0.342
#
# group_difference_8:
# ann_return = -1.2317  sharpe = -3.4251  maxdd = 3.6248  calmar_ratio = -0.3398
#
# group_difference_9:
# ann_return = -0.6  sharpe = -1.4773  maxdd = 1.6609  calmar_ratio = -0.3613
#
# group_difference_10:
# ann_return = 0.1026  sharpe = 0.1716  maxdd = 0.6972  calmar_ratio = 0.1471
